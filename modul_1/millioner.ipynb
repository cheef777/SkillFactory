# %%
import pandas as pd
df = pd.read_csv('g:/SkillFactory/миллионер/movie_bd_v5.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   imdb_id               1889 non-null   object
#  1   budget                1889 non-null   int64
#  2   revenue               1889 non-null   int64
#  3   original_title        1889 non-null   object
#  4   cast                  1889 non-null   object
#  5   director              1889 non-null   object
#  6   tagline               1889 non-null   object
#  7   overview              1889 non-null   object
#  8   runtime               1889 non-null   int64
#  9   genres                1889 non-null   object
#  10  production_companies  1889 non-null   object
#  11  release_date          1889 non-null   object
#  12  vote_average          1889 non-null   float64
#  13  release_year          1889 non-null   int64
# dtypes: float64(1), int64(4), object(9)
# ...

# %%
df.sample(5)
# Out:
#         imdb_id     budget    revenue     original_title  \
# 312   tt0971209   14000000   22852638  A Perfect Getaway
# 823   tt1637706   10000000   17273593  Our Idiot Brother
# 1189  tt1690953   76000000  970761885    Despicable Me 2
# 1253  tt1860353  135000000  282570682              Turbo
# 1674  tt0480249  150000000  585349010        I Am Legend
#
#                                                    cast  \
# 312   Milla Jovovich|Timothy Olyphant|Steve Zahn|Chr...
# 823   Paul Rudd|Elizabeth Banks|Zooey Deschanel|Emil...
# 1189  Steve Carell|Kristen Wiig|Benjamin Bratt|Miran...
# 1253  Ryan Reynolds|Paul Giamatti|Michael PeÃ±a|Samu...
# 1674  Will Smith|Alice Braga|Charlie Tahan|Salli Ric...
#
#                         director  \
# 312                  David Twohy
# 823                 Jesse Peretz
# 1189  Pierre Coffin|Chris Renaud
# 1253                 David Soren
# 1674            Francis Lawrence
#
#                                            tagline  \
# ...

# %%
df.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %%
answer_auto = {}

# %%
answer1 = df[df.budget ==df.budget.max()]['original_title'].iloc[0]
answer1 = answer1 + ' ' + '(' + df[df.budget ==df.budget.max()]['imdb_id'].iloc[0] + ')'
ss1 = ['The Dark Knight Rises (tt1345836)',
     'Spider-Man 3 (tt0413300)',
     'Avengers: Age of Ultron (tt2395427)',
     'The Warrior\'s Way (tt1032751)',
     'Pirates of the Caribbean: On Stranger Tides (tt1298650)']
if str(answer1) in ss1:
    answer_auto['1'] = str(ss1.index(answer1)+1) + '. ' + answer1
answer_auto['1']
# Out:
# '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)'

# %%
answer2 = df[df.runtime ==df.runtime.max()]['original_title'].iloc[0]
answer2 = answer2 + ' ' + '(' + df[df.runtime == df.runtime.max()]['imdb_id'].iloc[0] + ')'
ss2 = ['The Lord of the Rings: The Return of the King (tt0167260)',
     'Gods and Generals (tt0279111)',
     'King Kong (tt0360717)',
     'Pearl Harbor (tt0213149)',
     'Alexander (tt0346491)']
if answer2 in ss2:
    answer_auto['2'] = str(ss2.index(answer2)+1) + '. ' + answer2
answer_auto['2']
# Out:
# '2. Gods and Generals (tt0279111)'

# %%
answer3 = df[df.runtime == df.runtime.min()]['original_title'].iloc[0]
answer3 = answer3 + ' ' + '(' + df[df.runtime == df.runtime.min()]['imdb_id'].iloc[0] + ')'
ss3 = ['Home on the Range (tt0299172)',
       'The Jungle Book 2 (tt0283426)',
       'Winnie the Pooh (tt1449283)',
       'Corpse Bride (tt0121164)',
       'Hoodwinked! (tt0443536)']
if answer3 in ss3:
    answer_auto['3'] = str(ss3.index(answer3)+1) + '. ' + answer3
answer_auto['3']
# Out:
# '3. Winnie the Pooh (tt1449283)'

# %%
df.describe().loc['mean', 'runtime']
# Out:
# 109.6585494970884

# %%
df[df.runtime ==df.runtime.max()]
# Out:
#         imdb_id    budget   revenue     original_title  \
# 1157  tt0279111  56000000  12923936  Gods and Generals
#
#                                                    cast           director  \
# 1157  Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...  Ronald F. Maxwell
#
#                                   tagline  \
# 1157  The nations heart was touched by...
#
#                                                overview  runtime  \
# 1157  The film centers mostly around the personal an...      214
#
#                  genres                production_companies release_date  \
# 1157  Drama|History|War  Turner Pictures|Antietam Filmworks    2/21/2003
#
#       vote_average  release_year
# 1157           5.8          2003

# %%
df[df.budget ==df.budget.max()]
# Out:
#        imdb_id     budget     revenue  \
# 723  tt1298650  380000000  1021683000
#
#                                   original_title  \
# 723  Pirates of the Caribbean: On Stranger Tides
#
#                                                   cast      director  \
# 723  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...  Rob Marshall
#
#                          tagline  \
# 723  Live Forever Or Die Trying.
#
#                                               overview  runtime  \
# 723  Captain Jack Sparrow crosses paths with a woma...      136
#
#                        genres  \
# 723  Adventure|Action|Fantasy
#
#                                   production_companies release_date  \
# 723  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
#
#      vote_average  release_year
# 723           6.3          2011

# %%
df[df.runtime ==df.runtime.min()]
# Out:
#        imdb_id    budget   revenue   original_title  \
# 768  tt1449283  30000000  14460000  Winnie the Pooh
#
#                                                   cast  \
# 768  Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
#
#                       director   tagline  \
# 768  Stephen Anderson|Don Hall  Oh Pooh.
#
#                                               overview  runtime  \
# 768  During an ordinary day in Hundred Acre Wood, W...       63
#
#                genres                               production_companies  \
# 768  Animation|Family  Walt Disney Pictures|Walt Disney Animation Stu...
#
#     release_date  vote_average  release_year
# 768    4/13/2011           6.8          2011

# %%
answer5 = str(int(df.runtime.median()))
ss5 = ['107',
       '112',
       '101',
       '120',
       '115']
if answer5 in ss5:
    answer_auto['5'] = str(ss5.index(answer5)+1)+ '. ' + answer5
answer_auto['5']
# Out:
# '1. 107'

# %%
df.describe().loc['50%', 'runtime']
# Out:
# 107.0

# %%
answer4 = str(int(round(df.runtime.mean(),0)))
ss4 = ['115',
      '110',
      '105',
      '120',
      '100']
if answer4 in ss4:
    answer_auto['4'] = str(ss4.index(answer4)+1)+ '. ' + answer4
answer_auto['4']
# Out:
# '2. 110'

# %%
answer_auto
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '2. Gods and Generals (tt0279111)',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '2. 110',
#  '5': '1. 107'}

# %%
df['profit'] = 0
for i in range(len(df)):
    df.loc[i, 'profit'] = df.loc[i, 'revenue'] - df.loc[i, 'budget']

# %%
answer6 = df[df.profit == df.profit.max()]['original_title'].iloc[0]
answer6 = answer6 + ' ' + '(' + df[df.profit == df.profit.max()]['imdb_id'].iloc[0] + ')'
ss6 = ['The Avengers (tt0848228)',
        'Minions (tt2293640)',
        'Star Wars: The Force Awakens (tt2488496)',
        'Furious 7 (tt2820852)',
        'Avatar (tt0499549)']
if answer6 in ss6:
    answer_auto['6'] = str(ss6.index(answer6)+1) + '. ' + answer6
answer_auto['6']
# Out:
# '5. Avatar (tt0499549)'

# %%
answer7 = df[df.profit == df.profit.min()]['original_title'].iloc[0]
answer7 = answer7 + ' ' + '(' + df[df.profit == df.profit.min()]['imdb_id'].iloc[0] + ')'
ss7 = ['Supernova (tt0134983)',
        'Frozen (tt2294629)',
        'Flushed Away (tt0424095)',
        'The Adventures of Pluto Nash (tt0180052)',
        'The Lone Ranger (tt1210819)']
if answer7 in ss7:
    answer_auto['7'] = str(ss7.index(answer7)+1) + '. ' + answer7
answer_auto['7']
# Out:
# '5. The Lone Ranger (tt1210819)'

# %%
df.describe().loc['max', 'profit']
# Out:
# 2544505847.0

# %%
answer8 = str(df[df.revenue > df.budget].count()['original_title'])
ss8 = ['1478', 
        '1520',
        '1241',
        '1135',
        '1398']
if answer8 in ss8:
    answer_auto['8'] = str(ss8.index(answer8)+1) + '. ' + answer8
answer_auto['8']
# Out:
# '1. 1478'

# %%
df1 = df[df.release_year == 2008]
answer9 = df1[df1.revenue == df1.revenue.max()]['original_title'].iloc[0]
answer9 = answer9 + ' ' + '(' + df1[df1.revenue == df1.revenue.max()]['imdb_id'].iloc[0] + ')'
ss9 = ['Madagascar: Escape 2 Africa (tt0479952)',
        'Iron Man (tt0371746)',
        'Kung Fu Panda (tt0441773)',
        'The Dark Knight (tt0468569)',
        'Mamma Mia! (tt0795421)']
if answer9 in ss9:
    answer_auto['9'] = str(ss9.index(answer9)+1) + '. ' + answer9
answer_auto['9']
# Out:
# '4. The Dark Knight (tt0468569)'

# %%
df.genres.str.split('|').explode().value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: genres, dtype: int64

# %%
# мой код для решения данного вопроса:
# сортируем таблицу по годам выпуска
df2 = df[(df.release_year >= 2012) & (df.release_year <= 2014)]
# выбираем минимальную прибыль и берем название фильма
answer10 = df2[df2.profit == df2.profit.min()]['original_title'].iloc[0]
# добавляем к названию фильма его индедификатор в скобках
answer10 = answer10 + ' ' + '(' + df2[df2.profit == df2.profit.min()]['imdb_id'].iloc[0] + ')'
ss10 = ['Winter\'s Tale (tt1837709)', # создаем список ответов
        'Stolen (tt1656186)',
        'Broken City (tt1235522)',
        'Upside Down (tt1374992)',
        'The Lone Ranger (tt1210819)']
if answer10 in ss10:   # проверяем ответ 
    answer_auto['10'] = str(ss10.index(answer10)+1) + '. ' + answer10  # заполняем словарь по шаблону
answer_auto['10']
# Out:
# '5. The Lone Ranger (tt1210819)'

# %%
answer11 = df.genres.str.split('|').explode().value_counts().index[0]
ss11 = ['Action',
        'Adventure',
        'Drama',
        'Comedy',
        'Thriller']
if answer11 in ss11:
    answer_auto['11'] = str(ss11.index(answer11)+1) + '. ' + answer11
answer_auto['11']
# Out:
# '3. Drama'

# %%
from collections import Counter
df50 = df[df.profit > 0]
df51 = df50['genres']
df51 = df51.str.split('|').explode().value_counts() #.index[0]
df51
#Counter(df51).most_common(1)[0]
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: genres, dtype: int64

# %%
answer12 = df[df.profit > 0]['genres'].str.split('|').explode().value_counts().index[0]
ss12 = ['Drama',
        'Comedy',
        'Action',
        'Thriller',
        'Adventure']
if answer12 in ss12:
    answer_auto['12'] = str(ss12.index(answer12)+1) + '. ' + answer12
answer_auto['12']
# Out:
# '1. Drama'

# %%
df50 = df[df.profit > 0]
df50.genres = df50.genres.str.split('|')
df50 = df50.explode('genres')
df50.genres.value_counts()
# Out:
# C:\Users\1\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: genres, dtype: int64

# %%
answer13 = df[df.profit > 0]['genres'].str.split('|').explode().value_counts().index[0]
ss13 = ['Drama',
        'Comedy',
        'Action',
        'Thriller',
        'Adventure']
if answer13 in ss13:
    answer_auto['13'] = str(ss13.index(answer13)+1) + '. ' + answer13
answer_auto['13']
# Out:
# '1. Drama'

# %%
answer13 = df.groupby(['director'])[['revenue']].sum().sort_values(['revenue'], ascending = False).index[0]
ss13 = ['Steven Spielberg',
        'Christopher Nolan',
        'David Yates',
        'James Cameron',
        'Peter Jackson']
if answer13 in ss13:
    answer_auto['13'] = str(ss13.index(answer13)+1) + '. ' + answer13
answer_auto['13']
# Out:
# '5. Peter Jackson'

# %%
df.groupby(['director'])[['revenue']].sum().value_counts()
# Out:
# revenue
# 6490593685    1
# 49263404      1
# 52572764      1
# 51424799      1
# 51053787      1
#              ..
# 207897944     1
# 206172544     1
# 206152503     1
# 204594016     1
# 2033165       1
# Length: 957, dtype: int64

# %%
df3 = df[df.genres.str.contains('Action')]
df3.director.value_counts()
# Out:
# Michael Bay           7
# Paul W.S. Anderson    7
# Robert Rodriguez      6
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Wolfgang Petersen     1
# David Leland          1
# Luke Greenfield       1
# Michel Gondry         1
# Ron Underwood         1
# Name: director, Length: 345, dtype: int64

# %%
df3 = df[df.genres == 'Action']
df3.director.value_counts()
# Out:
# Rob Cohen                2
# Ridley Scott             1
# Harald Zwart             1
# Joseph Kahn              1
# Sydney Pollack           1
# Andy Tennant             1
# Robert Rodriguez         1
# Marcus Nispel            1
# Rob Bowman               1
# Renny Harlin             1
# Christopher McQuarrie    1
# John Moore               1
# Andrew Davis             1
# Kevin Macdonald          1
# Paul McGuigan            1
# Name: director, dtype: int64

# %%
answer14 = df[df.genres.str.contains('Action')].director.str.split('|').explode().value_counts().index[0]
ss14 = ['Ridley Scott',
        'Guy Ritchie',
        'Robert Rodriguez',
        'Quentin Tarantino',
        'Tony Scott']
if answer14 in ss14:
    answer_auto['14'] = str(ss14.index(answer14)+1) + '. ' + answer14
answer_auto['14']
# Out:
# '3. Robert Rodriguez'

# %%
df4 = df[df['release_year'] == 2012]
df4 = df4[df4.revenue > df4.revenue.mean()].cast.str.split('|').explode().value_counts()
df4 = df4[df4 == df4.max()].index
# a = ['Nicolas Cage', 'Tom Hardy', 'Chris Hemsworth', 'Jim Sturgess', 'Emma Stone']
# for i in a:
#     if i in df4:
#         answer = i
# answer
# Out:
# 'Chris Hemsworth'

# %%
df4 = df[df['release_year'] == 2012].copy()
df4.cast = df4.cast.str.split('|')
df4 = df4.explode('cast')
answer15 = df4.groupby(['cast'])['revenue'].sum().sort_values(ascending = False).index[0]
ss15 = ['Nicolas Cage',
        'Tom Hardy',
        'Chris Hemsworth',
        'Jim Sturgess',
        'Emma Stone']
if answer15 in ss15:
    answer_auto['15'] = str(ss15.index(answer15)+1) + '. ' + answer15
answer_auto['15']
# Out:
# '3. Chris Hemsworth'

# %%
df4 = df[df['release_year'] == 2012].copy()
df4.cast = df4.cast.str.split('|')
df4 = df4.explode('cast')
answer15 = df4.revenue.sum().value_counts()
answer15.revenue.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-d56e17256055> in <module>
#       2 df4.cast = df4.cast.str.split('|')
#       3 df4 = df4.explode('cast')
# ----> 4 answer15 = df4.revenue.sum().value_counts()
#       5 answer15.revenue.value_counts()
#
# AttributeError: 'numpy.int64' object has no attribute 'value_counts'

# %%
df5 = df[df.budget > df.budget.mean()]
answer16 = df5.cast.str.split('|').explode().value_counts().index[0]
ss16 = ['Tom Cruise',
        'Mark Wahlberg',
        'Matt Damon',
        'Angelina Jolie',
        'Adam Sandler']
if answer16 in ss16:
    answer_auto['16'] = str(ss16.index(answer16)+1) + '. ' + answer16
answer_auto['16']
# Out:
# '3. Matt Damon'

# %%
df6 = df.groupby(['genres'])[['cast']].sum()
df6.cast.str.split('|').explode()
df6[df6 == 'Nicolas Cage'].index
# Out:
# Index(['Action', 'Action|Adventure',
#        'Action|Adventure|Animation|Family|Fantasy',
#        'Action|Adventure|Animation|Family|Science Fiction',
#        'Action|Adventure|Animation|Science Fiction|Thriller',
#        'Action|Adventure|Comedy', 'Action|Adventure|Comedy|Crime',
#        'Action|Adventure|Comedy|Crime|Thriller',
#        'Action|Adventure|Comedy|Drama|Family',
#        'Action|Adventure|Comedy|Drama|Mystery',
#        ...
#        'War|Drama|Action', 'War|Drama|History', 'War|Drama|History|Action',
#        'War|History|Action|Adventure|Drama', 'Western', 'Western|Adventure',
#        'Western|Animation|Adventure|Comedy|Family',
#        'Western|Animation|Family|Comedy|Music',
#        'Western|Drama|Adventure|Thriller', 'Western|History|War'],
#       dtype='object', name='genres', length=652)

# %%
df7 = df[df.cast.str.contains('Nicolas Cage')]
df8 = df7.genres.str.split('|').explode().value_counts().index[0]
df8
# Out:
# 'Action'

# %%
answer17 = df[df.cast.str.contains('Nicolas Cage')].genres.str.split('|').explode().value_counts().index[0]
ss17 = ['Drama',
        'Action',
        'Thriller',
        'Adventure',
        'Crime']
if answer17 in ss17:
    answer_auto['17'] = str(ss17.index(answer17)+1) + '. ' + answer17
answer_auto['17']
# Out:
# '2. Action'

# %%
pd.Series(df[df.budget > df.budget.mean()].cast.str.split('|').sum()).value_counts().index[0]
# Out:
# 'Matt Damon'

# %%
df9 = df.genres.str.split('|').explode()
df9.value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# Name: genres, dtype: int64

# %%
df10 = df[df.profit > 0]
df10 = df10.genres.str.split('|').explode().value_counts()
df10
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# Name: genres, dtype: int64

# %%
df11 = df[df.production_companies.str.contains('Paramount Pictures')]
answer18 = df11[df11.profit == df11.profit.min()]['original_title'].iloc[0]
answer18 = answer18 + ' ' + '(' + df11[df11.profit == df11.profit.min()]['imdb_id'].iloc[0] + ')'
ss18 = ['K-19: The Widowmaker (tt0267626)',
        'Next (tt0435705)',
        'Twisted (tt0315297)',
        'The Love Guru (tt0811138)',
        'The Fighter (tt0964517)']
if answer18 in ss18:
    answer_auto['18'] = str(ss18.index(answer18)+1) + '. ' + answer18
answer_auto['18']
# Out:
# '1. K-19: The Widowmaker (tt0267626)'

# %%
answer19 = str(df.groupby(['release_year'])[['revenue']].sum().sort_values(['revenue'], ascending = False).index[0])
ss19 = ['2014',
        '2008',
        '2012',
        '2002',
        '2015']
if answer19 in ss19:
    answer_auto['19'] = str(ss19.index(answer19)+1) + '. ' + answer19
answer_auto['19']
# Out:
# '5. 2015'

# %%
df13 = df[df.production_companies.str.contains('Warner Bros')]
answer20 = str(df13.groupby(['release_year'])[['profit']].sum().sort_values(['profit'], ascending = False).index[0])
ss20 = ['2014',
        '2008',
        '2012',
        '2010',
        '2015']
if answer20 in ss20:
    answer_auto['20'] = str(ss20.index(answer20)+1) + '. ' + answer20
answer_auto['20']
# Out:
# '1. 2014'

# %%
import datetime as dt
df.release_date[1].to_datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-243524b5b687> in <module>
#       1 import datetime as dt
# ----> 2 df.release_date[1].to_datetime
#
# AttributeError: 'str' object has no attribute 'to_datetime'

# %%
month = {1: 'Январь',
         2: 'Февраль',
         3: 'Март',
         4: 'Апрель',
         5: 'Май',
         6: 'Июнь',
         7: 'Июль',
         8: 'Август',
         9: 'Сентябрь',
         10: 'Октябрь',
         11: 'Ноябрь',
         12: 'Декабрь'}

# %%
month
# Out:
# {1: 'Январь',
#  2: 'Февраль',
#  3: 'Март',
#  4: 'Апрель',
#  5: 'Май',
#  6: 'Июнь',
#  7: 'Июль',
#  8: 'Август',
#  9: 'Сентябрь',
#  10: 'Октябрь',
#  11: 'Ноябрь',
#  12: 'Декабрь'}

# %%
df['date'] = pd.to_datetime(df["release_date"])
df14 = df
for i in range(len(df)):
    df14.loc[i,'Month'] = df.loc[i, 'date'].month
answer21 = month[int(df14.Month.value_counts().index[0])]
ss21 = ['Январь',
        'Июнь',
        'Декабрь',
        'Сентябрь',
        'Май']
if answer21 in ss21:
    answer_auto['21'] = str(ss21.index(answer21)+1) + '. ' + answer21
answer_auto['21']
# Out:
# '4. Сентябрь'

# %%
df15 = df14[ (df14.Month >=6) & (df14.Month<= 8)]
answer22 = str(len(df15))
ss22 = ['345',
        '450',
        '478',
        '523',
        '381']
if answer22 in ss22:
    answer_auto['22'] = str(ss22.index(answer22)+1) + '. ' + answer22
answer_auto['22']
# Out:
# '2. 450'

# %%
df16 = df14[(df14.Month == 12) | (df14.Month == 2) | (df14.Month == 1)]
answer23 = df16.director.str.split('|').explode().value_counts().index[0]
ss23 = ['Steven Soderbergh',
        'Christopher Nolan',
        'Clint Eastwood',
        'Ridley Scott',
        'Peter Jackson']
if answer23 in ss23:
    answer_auto['23'] = str(ss23.index(answer23)+1) + '. ' + answer23
answer_auto['23']
# Out:
# '5. Peter Jackson'

# %%
df16 = df14[(df14.Month == 12) | (df14.Month == 2) | (df14.Month == 1)]
df161 = df16
df161.director = df161.director.str.split('|')
df162 = df161
df162 = df162.explode('director')
df162.director.value_counts()
# Out:
# C:\Users\1\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# Peter Jackson            7
# Clint Eastwood           6
# Steven Soderbergh        6
# Martin Scorsese          4
# Nancy Meyers             4
#                         ..
# Steve Trenbirth          1
# Frank Darabont           1
# Barry Cook               1
# John Frankenheimer       1
# Christopher B. Landon    1
# Name: director, Length: 358, dtype: int64

# %%
df17 = df
df17['len_str'] = 0
for i in range(len(df17)):
    df17.loc[i,'len_str'] = len(df17.loc[i, 'original_title'])
# df17 = df17.groupby(['production_companies'])[['len_str']].max().sort_values(['len_str'], ascending = False)
df17[df17.len_str == df17.len_str.max()]
df17 = df17.production_companies.str.split('|').explode().value_counts()
df17
# Out:
# Universal Pictures                        173
# Warner Bros.                              168
# Paramount Pictures                        122
# Columbia Pictures                         117
# Twentieth Century Fox Film Corporation    109
#                                          ...
# Snoot Entertainment                         1
# Nine Yards Two Productions                  1
# Crystal Sky Pictures                        1
# Milagro Films                               1
# The Halcyon Company                         1
# Name: production_companies, Length: 1771, dtype: int64

# %%
df17[df17.len_str == df17.len_str.max()]['production_companies'].str.split('|').explode()
# Out:
# 1448    Twentieth Century Fox Film Corporation
# 1448                   Four By Two Productions
# Name: production_companies, dtype: object

# %%
df18 = df
df18['o'] = 0
df18['o'] = df18['overview'].apply(lambda x: len(x))
df18 =df18[ df18.o == df18.o.max()]
display(df18.production_companies.str.split('|').explode())
# Out:
# 711           Lions Gate Films
# 711    Lakeshore Entertainment
# 711         GreeneStreet Films
# 711      Midnight Picture Show
# Name: production_companies, dtype: object

# %%
df18 = df
df18['o'] = 0
df18['o'] = df18['overview'].apply(lambda x: len(x))
df18 = df18[df18.o > df18.o.mean()]
df18.production_companies.str.split('|').explode().value_counts()
# Out:
# Universal Pictures               93
# Warner Bros.                     81
# Paramount Pictures               61
# Columbia Pictures                58
# Relativity Media                 47
#                                  ..
# Fast Track Productions            1
# Avi Arad Productions              1
# Littlestar                        1
# Iron Horse Entertainment (II)     1
# The Halcyon Company               1
# Name: production_companies, Length: 1043, dtype: int64

# %%
ind = 0
max_avr = df.vote_average.max()
df20 = df.vote_average.value_counts(bins=100)
for i in df20.index:
    if max_avr in i: ind = i
df21 = df[df.vote_average > ind.left]
df21
# Out:
#        imdb_id     budget     revenue   original_title  \
# 599  tt0468569  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 599  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 599  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 599      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 599  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_average  release_year     profit  len_str    o
# 599           8.1          2008  816921825       15  396

# %%
import itertools as it
actor = df.cast.str.split('|').explode().unique()
count= []
ind = 0
for i in it.combinations(actor, 2):
    ind+=1
    
    
print(ind)
# Out:
# 5798715

# %%
df20 = df.vote_average.sort_values(ascending=False)
df22 = df[df.vote_average > df20.iloc[round(len(df20) / 100)]].sort_values(['vote_average'], ascending=False)
df22 = df22[['original_title', 'vote_average']]
answer = []
answer26 = ''
ss26 = [['Inside Out', 'The Dark Knight', '12 Years a Slave'], 
      ['BloodRayne', 'The Adventures of Rocky & Bullwinkle'],
      ['Batman Begins', 'The Lord of the Rings: The Return of the King', 'Upside Down'],
      ['300', 'Lucky Number Slevin', 'Kill Bill: Vol. 1'],
      ['Upside Down', 'Inside Out', 'Iron Man']]
for i in ss26:
    count = 0
    for j in i:
        if j in list(df22.original_title):
            count+=1
    if count == 3 or count == 2:
        answer.append(i)
for i in answer[0]:
    answer26 = answer26 + i +', '
answer_auto['26'] = str(ss26.index(answer[0])+1) + '. ' + answer26[:-2]
answer_auto['26']
# Out:
# '1. Inside Out, The Dark Knight, 12 Years a Slave'

# %%
df20 = df.vote_average.sort_values(ascending=False)
df20
# Out:
# 599     8.1
# 125     8.0
# 9       8.0
# 118     8.0
# 34      8.0
#        ...
# 1175    3.5
# 1760    3.4
# 1161    3.4
# 965     3.3
# 709     3.3
# Name: vote_average, Length: 1889, dtype: float64

# %%
answer[0][0]
# Out:
# 'Inside Out'

# %%
import itertools as it
answer27 = ''                                                  # это будет наш ответ
mov_acts_comb = []                                           # это комбинации пар
for cast in df.cast.str.split('|'):
    mov_acts_comb.extend(list(it.combinations(cast, 2)))     # составляем список пар актеров
mov_acts_pair = pd.Series(mov_acts_comb).value_counts()      # подсчитываем, сколько раз встречается каждая пара
mov_acts_pair = mov_acts_pair[mov_acts_pair == mov_acts_pair.max()]   # выбираем пары, которые встречаются чаще
mov_acts_pair = list(mov_acts_pair.index)         # из серии берем имена           
ss27 = ['Johnny Depp & Helena Bonham Carter',      # составляем список вариантов ответов
       'Ben Stiller & Owen Wilson',
       'Vin Diesel & Paul Walker',
       'Adam Sandler & Kevin James',
       'Daniel Radcliffe & Rupert Grint']
for i in mov_acts_pair:                           # выбираем правильный ответ
    for j in ss27:
        a3 = []
        a1 = j.split('&')
        for z in a1:
            a3.append(z.strip())
        a2 = list(i)
        if a3 == a2:
            answer27 = j
if answer27 in ss27:  # проверяем ответ 
    answer_auto['27'] = str(ss27.index(answer27)+1) + '. ' + answer27
answer_auto['27']
# Out:
# '5. Daniel Radcliffe & Rupert Grint'

# %%
for cast in df.cast.str.split('|'):
    print(cast)
# Out:
# ['Chris Pratt', 'Bryce Dallas Howard', 'Irrfan Khan', "Vincent D'Onofrio", 'Nick Robinson']
# ['Tom Hardy', 'Charlize Theron', 'Hugh Keays-Byrne', 'Nicholas Hoult', 'Josh Helman']
# ['Shailene Woodley', 'Theo James', 'Kate Winslet', 'Ansel Elgort', 'Miles Teller']
# ['Harrison Ford', 'Mark Hamill', 'Carrie Fisher', 'Adam Driver', 'Daisy Ridley']
# ['Vin Diesel', 'Paul Walker', 'Jason Statham', 'Michelle Rodriguez', 'Dwayne Johnson']
# ['Leonardo DiCaprio', 'Tom Hardy', 'Will Poulter', 'Domhnall Gleeson', 'Paul Anderson']
# ['Arnold Schwarzenegger', 'Jason Clarke', 'Emilia Clarke', 'Jai Courtney', 'J.K. Simmons']
# ['Matt Damon', 'Jessica Chastain', 'Kristen Wiig', 'Jeff Daniels', 'Michael PeÃ±a']
# ['Sandra Bullock', 'Jon Hamm', 'Michael Keaton', 'Allison Janney', 'Steve Coogan']
# ['Amy Poehler', 'Phyllis Smith', 'Richard Kind', 'Bill Hader', 'Lewis Black']
# ['Daniel Craig', 'Christoph Waltz', 'LÃ©a Seydoux', 'Ralph Fiennes', 'Monica Bellucci']
# ...

# %%
df100 = df
df100.cast = df100.cast.str.split('|')
df100 = df100.explode('cast')
df100
# Out:
#         imdb_id     budget     revenue  original_title                 cast  \
# 0     tt0369610  150000000  1513528810  Jurassic World          Chris Pratt
# 0     tt0369610  150000000  1513528810  Jurassic World  Bryce Dallas Howard
# 0     tt0369610  150000000  1513528810  Jurassic World          Irrfan Khan
# 0     tt0369610  150000000  1513528810  Jurassic World    Vincent D'Onofrio
# 0     tt0369610  150000000  1513528810  Jurassic World        Nick Robinson
# ...         ...        ...         ...             ...                  ...
# 1888  tt0163676   15000000     5217498    The In Crowd           Susan Ward
# 1888  tt0163676   15000000     5217498    The In Crowd         Lori Heuring
# 1888  tt0163676   15000000     5217498    The In Crowd       Matthew Settle
# 1888  tt0163676   15000000     5217498    The In Crowd        Nathan Bexton
# 1888  tt0163676   15000000     5217498    The In Crowd          Tess Harper
#
#              director                       tagline  \
# ...

# %%
df101 = df
df101['len_name'] = df101.original_title.apply(lambda x: len(x))
df101.production_companies = df101.production_companies.str.split('|')
df101 = df101.explode('production_companies')

# %%
answer24 = df101.groupby(['production_companies'])[['len_name']].mean().sort_values(['len_name'], ascending = False).index[0]
ss24 = ['Universal Pictures (Universal)',
        'Warner Bros',
        'Jim Henson Company, The',
        'Paramount Pictures',
        'Four By Two Productions']
if answer24 in ss24:
    answer_auto['24'] = str(ss24.index(answer24)+1) + '. ' + answer24
answer_auto['24']
# Out:
# '5. Four By Two Productions'

# %%
df200 = df
df200['len_overview'] = df200.overview.apply(lambda x: len(x.split()))
df200.production_companies = df200.production_companies.str.split('|')
df200 = df200.explode('production_companies')
answer25 = df200.groupby(['production_companies'])[['len_overview']].mean().sort_values(['len_overview'], ascending = False)
answer25 = answer25.index[0]
ss25 = ['Universal Pictures',
        'Warner Bros',
        'Midnight Picture Show',
        'Paramount Pictures',
        'Total Entertainment']
if answer25 in ss25:
    answer_auto['25'] = str(ss25.index(answer25)+1) + '. ' + answer25
answer_auto['25']
# Out:
# '3. Midnight Picture Show'

# %%
df200.groupby(['production_companies'])[['len_overview']].mean().sort_values(['len_overview'], ascending = False).index[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-a86da927bade> in <module>
# ----> 1 df200.groupby(['production_companies'])[['len_overview']].mean().sort_values(['len_overview'], ascending = False).index[0]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
from collections import Counter
def list_creator(series):
    ''' The function takes Pandas.Series
        then create a list from a string
        then create collections.Counter 
        and return it '''
    return Counter([unit for string in series for unit in string.split('|')])
genre = list_creator(df.genres)
genre.most_common(1)[0][0]
# Out:
# 'Drama'

# %%
Counter([unit for string in df.genres for unit in string.split('|')]).most_common(1)[0][0]
# Out:
# 'Drama'

# %%
df[df.genres.str.contains('Action')].director.str.split('|')

# %%
Counter([a for string in df[df.genres.str.contains('Action')].director for a in string.split('|')]).most_common(1)[0][0]
# Out:
# 'Robert Rodriguez'

# %%
list(df.genres.str.split('|'))
# Out:
# [['Action', 'Adventure', 'Science Fiction', 'Thriller'],
#  ['Action', 'Adventure', 'Science Fiction', 'Thriller'],
#  ['Adventure', 'Science Fiction', 'Thriller'],
#  ['Action', 'Adventure', 'Science Fiction', 'Fantasy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Western', 'Drama', 'Adventure', 'Thriller'],
#  ['Science Fiction', 'Action', 'Thriller', 'Adventure'],
#  ['Drama', 'Adventure', 'Science Fiction'],
#  ['Family', 'Animation', 'Adventure', 'Comedy'],
#  ['Comedy', 'Animation', 'Family'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Science Fiction', 'Fantasy', 'Action', 'Adventure'],
#  ['Drama', 'Science Fiction'],
#  ['Action', 'Comedy', 'Science Fiction'],
#  ['Action', 'Adventure', 'Science Fiction'],
#  ['Crime', 'Drama', 'Mystery', 'Western'],
#  ['Crime', 'Action', 'Thriller'],
#  ['Science Fiction', 'Action', 'Adventure'],
#  ['Romance', 'Fantasy', 'Family', 'Drama'],
#  ['War', 'Adventure', 'Science Fiction'],
# ...
